# %% [markdown]
# <a href="https://colab.research.google.com/github/Harika-11/AI-ML-Tasks/blob/main/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %%
df = pd.read_csv("/content/test.csv")
df.head()
# Out:
#    PassengerId  Pclass  Sex       Age     SibSp     Parch      Fare  \
# 0          892       3    1  0.455241 -0.689261 -0.538447 -0.903049
# 1          893       3    0  1.315112  1.392053 -0.538447 -1.002190
# 2          894       2    1  1.828669 -0.689261 -0.538447 -0.643707
# 3          895       3    1 -0.106026 -0.689261 -0.538447 -0.778850
# 4          896       3    0 -0.506377  1.392053  1.806630 -0.364663
#
#    FamilySize  Embarked_C  Embarked_Q  Embarked_S
# 0           1       False        True       False
# 1           2       False       False        True
# 2           1       False        True       False
# 3           1       False       False        True
# 4           3       False       False        True

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# FamilySize     0
# Embarked_C     0
# Embarked_Q     0
# Embarked_S     0
# dtype: int64

# %%
df["Age"].fillna(df["Age"].median(), inplace=True)
# Out:
# /tmp/ipykernel_300/2097741607.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].median(), inplace=True)

# %%
df.dropna(inplace=True)

# %%
le = LabelEncoder()
df["Sex"] = le.fit_transform(df["Sex"])

# %%
scaler = MinMaxScaler()

cols_to_scale = ["Age", "Fare", "SibSp", "Parch"]
df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])

# %%
df.to_csv("titanic_cleaned.csv", index=False)

# %%
plt.figure()
plt.hist(df["Fare"], bins=30)
plt.title("Fare Distribution")
plt.xlabel("Normalized Fare")
plt.ylabel("Frequency")
plt.show()

# %%
gender_counts = df["Sex"].value_counts()

plt.figure()
plt.bar(gender_counts.index, gender_counts.values)
plt.xticks([0,1], ["Female", "Male"])
plt.title("Gender Distribution")
plt.show()
